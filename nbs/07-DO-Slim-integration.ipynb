# %%
import requests
import pandas as pd
from io import StringIO

# %% [markdown]
# ## Xrefs for DO-Slim have been provided by dhimmel
#
# Download the files from github and use them to convert the disorders to a slim version

# %% [markdown]
# r = requests.get('https://raw.githubusercontent.com/dhimmel/disease-ontology/gh-pages/data/xrefs-prop-slim.tsv')
#
# file = StringIO(r.text)
# xref = pd.read_csv(file, sep='\t')

# %%
xref = pd.read_table('../../disease-ontology/data/xrefs-prop-slim.tsv')

# %%
xref.head(2)
# Out:
#    doid_code           doid_name resource resource_id
# 0  DOID:2531  hematologic cancer      CSP   2004-1600
# 1  DOID:2531  hematologic cancer      CSP   2004-1803

# %%
# load the DOID to UMLS mapper
doid_to_umls = pd.read_csv('../doid-to-umls.csv').set_index('doid')['umlscui'].to_dict()

# %%
xref = xref.query('resource == "UMLS"')
print('{} unique CUIs can be mapped to DO Slim'.format(len(xref)))
xref['parent_cui'] = xref['doid_code'].apply(lambda c: doid_to_umls.get(c, float('NaN')))
# Out:
# 2420 unique CUIs can be mapped to DO Slim

# %%
idx = xref['parent_cui'].isnull()
xref.loc[idx].drop_duplicates(subset=['doid_code'])
# Out:
#           doid_code                              doid_name resource  \
# 2105   DOID:0060119                         pharynx cancer     UMLS
# 4660   DOID:0060073                lymphatic system cancer     UMLS
# 9056   DOID:0050777                       Joubert syndrome     UMLS
# 9966   DOID:0050581                          brachydactyly     UMLS
# 10451  DOID:0060668                            anencephaly     UMLS
# 10835  DOID:0050545                    visceral heterotaxy     UMLS
# 10941  DOID:0050591                         tooth agenesis     UMLS
# 11688  DOID:0050674  congenital bile acid synthesis defect     UMLS
# 11882    DOID:12859                      choreatic disease     UMLS
#
#       resource_id parent_cui
# 2105     C0031347        NaN
# 4660     C0024224        NaN
# 9056     C2745997        NaN
# 9966     C1300268        NaN
# 10451    C0020225        NaN
# 10835    C0037221        NaN
# 10941    C0399352        NaN
# 11688    C1843116        NaN
# 11882    C0264746        NaN

# %% [markdown]
# 9 DOIDs could not be mapped directly to UMLS.  We will use the DOID as the identifier in these two instances

# %%
xref.loc[idx, 'parent_cui'] = xref.loc[idx, 'doid_code']
xref.loc[idx].drop_duplicates(subset=['doid_code'])
# Out:
#           doid_code                              doid_name resource  \
# 2105   DOID:0060119                         pharynx cancer     UMLS
# 4660   DOID:0060073                lymphatic system cancer     UMLS
# 9056   DOID:0050777                       Joubert syndrome     UMLS
# 9966   DOID:0050581                          brachydactyly     UMLS
# 10451  DOID:0060668                            anencephaly     UMLS
# 10835  DOID:0050545                    visceral heterotaxy     UMLS
# 10941  DOID:0050591                         tooth agenesis     UMLS
# 11688  DOID:0050674  congenital bile acid synthesis defect     UMLS
# 11882    DOID:12859                      choreatic disease     UMLS
#
#       resource_id    parent_cui
# 2105     C0031347  DOID:0060119
# 4660     C0024224  DOID:0060073
# 9056     C2745997  DOID:0050777
# 9966     C1300268  DOID:0050581
# 10451    C0020225  DOID:0060668
# 10835    C0037221  DOID:0050545
# 10941    C0399352  DOID:0050591
# 11688    C1843116  DOID:0050674
# 11882    C0264746    DOID:12859

# %% [markdown]
# ## Find more relations with slim mapping
#
# Daniel also has DOID to DO-Slim mapping file.  Lets see if we can use it along with our doid to umls mapper to pick up any new relations.

# %% [markdown]
# r = requests.get('https://raw.githubusercontent.com/dhimmel/disease-ontology/gh-pages/data/slim-terms-prop.tsv')
#
# file = StringIO(r.text)
# do_slim = pd.read_csv(file, sep='\t')

# %%
do_slim = pd.read_table('../../disease-ontology/data/slim-terms-prop.tsv')

# %%
do_slim.head(2)
# Out:
#         slim_id                      slim_name   subsumed_id  \
# 0  DOID:0050144            Kartagener syndrome  DOID:0050144
# 1  DOID:0050156  idiopathic pulmonary fibrosis  DOID:0050156
#
#                    subsumed_name  min_distance
# 0            Kartagener syndrome             0
# 1  idiopathic pulmonary fibrosis             0

# %%
do_slim['slim_cui'] = do_slim['slim_id'].apply(lambda i: doid_to_umls.get(i, float('NaN')))
do_slim['subsumed_cui'] = do_slim['subsumed_id'].apply(lambda i: doid_to_umls.get(i, float('NaN')))

# %%
idx = do_slim['slim_cui'].isnull()
do_slim.loc[idx].drop_duplicates(subset=['slim_id'])
# Out:
#            slim_id                                          slim_name  \
# 47    DOID:0050489                                multinodular goiter
# 91    DOID:0050541                 Charcot-Marie-Tooth disease type 4
# 104   DOID:0050542                 Charcot-Marie-Tooth disease type X
# 111   DOID:0050544                                 hypermethioninemia
# 115   DOID:0050545                                visceral heterotaxy
# 135   DOID:0050564           autosomal dominant nonsyndromic deafness
# 190   DOID:0050565          autosomal recessive nonsyndromic deafness
# 270   DOID:0050566                     X-linked nonsyndromic deafness
# 271   DOID:0050569                                    Seckel syndrome
# 272   DOID:0050572                                 cone-rod dystrophy
# 295   DOID:0050576                              Senior-Loken syndrome
# 297   DOID:0050581                                      brachydactyly
# 316   DOID:0050590                      severe congenital neutropenia
# 317   DOID:0050591                                     tooth agenesis
# 319   DOID:0050628                      advanced sleep phase syndrome
# 323   DOID:0050629                         Aicardi-Goutieres syndrome
# 324   DOID:0050632                            oculocutaneous albinism
# 325   DOID:0050635                alternating hemiplegia of childhood
# 326   DOID:0050639                      primary cutaneous amyloidosis
# 327   DOID:0050640                              anauxetic dysplasia 1
# 328   DOID:0050644                  arterial calcification of infancy
# 329   DOID:0050646                              distal arthrogryposis
# 330   DOID:0050650                       familial atrial fibrillation
# 333   DOID:0050674              congenital bile acid synthesis defect
# 341   DOID:0050690                                        brachyolmia
# 343   DOID:0050713            fatal infantile encephalocardiomyopathy
# 348   DOID:0050764                                  Armfield syndrome
# 349   DOID:0050768  mitochondrial complex V (ATP synthase) deficie...
# 350   DOID:0050776     non-syndromic X-linked intellectual disability
# 351   DOID:0050777                                   Joubert syndrome
# ...            ...                                                ...
# 643   DOID:0060668                                        anencephaly
# 648   DOID:0060673                                     Peters anomaly
# 649   DOID:0060681  autosomal dominant nocturnal frontal lobe epil...
# 656   DOID:0060693                                   Brunner Syndrome
# 657   DOID:0060695                                      hyperekplexia
# 661   DOID:0060704                       lymphoproliferative syndrome
# 666   DOID:0060710        autosomal recessive congenital ichthyosis 2
# 667   DOID:0060711        autosomal recessive congenital ichthyosis 3
# 668   DOID:0060712       autosomal recessive congenital ichthyosis 4A
# 669   DOID:0060713       autosomal recessive congenital ichthyosis 4B
# 670   DOID:0060714        autosomal recessive congenital ichthyosis 5
# 671   DOID:0060715        autosomal recessive congenital ichthyosis 6
# 672   DOID:0060716        autosomal recessive congenital ichthyosis 7
# 672   DOID:0060716        autosomal recessive congenital ichthyosis 7
# 673   DOID:0060717        autosomal recessive congenital ichthyosis 8
# 674   DOID:0060718        autosomal recessive congenital ichthyosis 9
# 675   DOID:0060719       autosomal recessive congenital ichthyosis 10
# 676   DOID:0060720       autosomal recessive congenital ichthyosis 11
# 678   DOID:0080028   spondyloepimetaphyseal dysplasia, Strudwick type
# 679   DOID:0080033                        craniometaphyseal dysplasia
# 680   DOID:0080109                          infantile myofibromatosis
# 681   DOID:0080110                        multiple pterygium syndrome
# 682   DOID:0080143     congenital fibrosis of the extraocular muscles
# 683   DOID:0080153     medium chain acyl-CoA dehydrogenase deficiency
# 685   DOID:0080155  very long chain acyl-CoA dehydrogenase deficiency
# 686   DOID:0080173  bladder exstrophy-epispadias-cloacal exstrophy...
# 689   DOID:0080193             superior semicircular canal dehiscence
# 690   DOID:0080196     mandibulofacial dysostosis, Guion-Almeida type
# 1259    DOID:12859                                  choreatic disease
# 1522    DOID:14264                           benign neonatal seizures
# 3405     DOID:8158                  complement component 5 deficiency
#
#       min_distance slim_cui subsumed_cui
# 47               0      NaN          NaN
# 91               0      NaN          NaN
# 104              0      NaN          NaN
# 111              0      NaN          NaN
# 115              0      NaN          NaN
# 135              0      NaN          NaN
# 190              0      NaN          NaN
# 270              0      NaN          NaN
# 271              0      NaN          NaN
# 272              0      NaN          NaN
# 295              0      NaN          NaN
# 297              0      NaN          NaN
# 316              0      NaN          NaN
# 317              0      NaN          NaN
# 319              0      NaN          NaN
# 323              0      NaN          NaN
# 324              0      NaN          NaN
# 325              0      NaN          NaN
# 326              0      NaN          NaN
# 327              0      NaN          NaN
# 328              0      NaN          NaN
# 329              0      NaN          NaN
# 330              0      NaN          NaN
# 333              0      NaN          NaN
# 341              0      NaN          NaN
# 343              0      NaN          NaN
# 348              0      NaN          NaN
# 349              0      NaN          NaN
# 350              0      NaN          NaN
# 351              0      NaN          NaN
# ...            ...      ...          ...
# 643              0      NaN          NaN
# 648              0      NaN          NaN
# 649              0      NaN          NaN
# 656              0      NaN          NaN
# 657              0      NaN          NaN
# 661              0      NaN          NaN
# 666              0      NaN          NaN
# 667              0      NaN          NaN
# 668              0      NaN          NaN
# 669              0      NaN          NaN
# 670              0      NaN          NaN
# 671              0      NaN          NaN
# 672              0      NaN          NaN
# 673              0      NaN          NaN
# 674              0      NaN          NaN
# 675              0      NaN          NaN
# 676              0      NaN          NaN
# 678              0      NaN          NaN
# 679              0      NaN          NaN
# 680              0      NaN          NaN
# 681              0      NaN          NaN
# 682              0      NaN          NaN
# 683              0      NaN          NaN
# 685              0      NaN          NaN
# 686              0      NaN          NaN
# 689              0      NaN          NaN
# 690              0      NaN          NaN
# 1259             0      NaN          NaN
# 1522             0      NaN          NaN
# 3405             0      NaN          NaN
#
# [169 rows x 7 columns]

# %% [markdown]
# More are not able to be mapped, will still use the same doid parents

# %%
do_slim.loc[idx, 'slim_cui'] = do_slim.loc[idx, 'slim_id']

# %%
do_slim = do_slim.rename(columns={'slim_name': 'doid_name', 'subsumed_cui':'resource_id', 
                                  'slim_cui': 'parent_cui'})[['doid_name', 'resource_id', 'parent_cui']]


final = (pd.concat([xref, do_slim])
           .dropna(subset=['resource_id', 'parent_cui'])
           .drop_duplicates(subset=['resource_id', 'parent_cui']))
         
print('{} new mappings found by incorporating do-slim'.format(len(final) - len(xref)) )
# Out:
# 116 new mappings found by incorporating do-slim

# %%
final.to_csv('../data/DOSlim_mapping_info.csv', index=False)

# %% [markdown]
# ## Start mapping network to slim

# %%
to_slim = final.set_index('resource_id')['parent_cui'].to_dict()
to_slim_name = final.set_index('resource_id')['doid_name'].to_dict()

# %%
nodes = pd.read_csv('../data/nodes_7_metanode.csv')
edges = pd.read_csv('../data/edges_7_metanode.csv', converters={'pmids':eval})

# %%
nodeid_to_name = nodes.set_index(':ID')['name'].to_dict()

# %%
nodes['name'] = nodes[':ID'].apply(lambda i: to_slim_name.get(i, nodeid_to_name[i]))
nodes[':ID'] = nodes[':ID'].apply(lambda i: to_slim.get(i, i))

# %%
edges[':START_ID'] = edges[':START_ID'].apply(lambda i: to_slim.get(i, i))
edges[':END_ID'] = edges[':END_ID'].apply(lambda i: to_slim.get(i, i))

# %% [markdown]
# ## Map indications to slim

# %%
ind = pd.read_csv('../data/indications.csv')

# %%
ind.head(2)
# Out:
#    dc_struct_id compound_umlscui compound_name relationship  dc_disease_id  \
# 0          5203         C3661315     rucaparib   indication       21000533
# 1          5202         C4044947   baricitinib   indication       21002805
#
#   disease_umlscui              disease_name disease_umls_semantic_type  \
# 0        C1140680  Malignant tumor of ovary                       T191
# 1        C0003873      Rheumatoid arthritis                       T047
#
#   date_approved
# 0    2016-12-19
# 1    2017-02-13

# %%
did_to_name = ind.set_index('disease_umlscui')['disease_name'].to_dict()

ind['disease_name'] = ind['disease_umlscui'].apply(lambda c: to_slim_name.get(c, did_to_name[c]))
ind['disease_umlscui'] = ind['disease_umlscui'].apply(lambda c: to_slim.get(c, c))

# %%
ind = ind.drop_duplicates(subset=['compound_umlscui', 'disease_umlscui'])

print("{} nodes, {} edges, {} indications".format(0, 0, len(ind)))
# Out:
# 0 nodes, 0 edges, 8182 indications

# %%
ind.to_csv('../data/indications_slim.csv', index=False)

# %% [markdown]
# ## De-duplicate and Save Files

# %%
# %%time

print("{} nodes, {} edges, {} indications".format(len(nodes), len(edges), len(ind)))

nodes = nodes.drop_duplicates(subset=':ID')

# Some edges now duplicated, de-duplicate and combine pmids
grpd = edges.groupby([':START_ID', ':END_ID', ':TYPE'])
edges = grpd['pmids'].apply(lambda Series: set.union(*Series.values)).reset_index()
# re-count the pmid numbers
edges['n_pmids'] = edges['pmids'].apply(len)

ind = ind.drop_duplicates(subset=['compound_umlscui', 'disease_umlscui'])

print("{} nodes, {} edges, {} indications".format(len(nodes), len(edges), len(ind)))
# Out:
# 215817 nodes, 10344754 edges, 8264 indications
# 214590 nodes, 10230594 edges, 8176 indications
# CPU times: user 14min 39s, sys: 3.21 s, total: 14min 43s
# Wall time: 14min 43s

# %%
nodes.to_csv('../data/nodes_7_metanode_slim.csv', index=False)
edges.to_csv('../data/edges_7_metanode_slim.csv', index=False)
ind.to_csv('../data/indications_slim.csv', index=False)

# %%
slim_ids = list(final['parent_cui'].unique())
len(ind.query('disease_umlscui in @slim_ids'))
# Out:
# 1096

# %%
import pickle
pickle.dump(slim_ids, open('../data/slim_cuis.pkl', 'wb'))
