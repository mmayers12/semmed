# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
with open('/home/mmayers/.my.cnf') as fin:
    for line in fin:
        if line.startswith('password'):
            pw=line.strip().split('=')[-1].strip("'")

# %%
engine = create_engine('mysql+pymysql://root:'+pw+'@localhost/semmed_db', echo=False)

# %%
cit_df = pd.read_sql('SELECT * FROM CITATIONS LIMIT 10;', con=engine)
cit_df
# Out:
#        PMID       ISSN           DP        EDAT  PYEAR
# 0         1  0006-2944     1975 Jun  1976 01 16   1975
# 1        10  0006-2952   1975 Sep 1  1976 01 23   1975
# 2       100  0547-6844         1975  1976 03 01   1975
# 3      1000  0264-6021     1975 Sep  1976 02 21   1975
# 4     10000  0006-3002  1976 Sep 28  1976 12 30   1976
# 5    100000  0160-3450     1978 Sep  1978 11 18   1978
# 6   1000000  0006-3363     1976 Dec  1977 02 16   1976
# 7  10000000  0163-1829  1991 Aug 15   1991-8-15   1991
# 8  10000001  0163-1829  1991 Aug 15   1991-8-15   1991
# 9  10000002  0163-1829  1991 Aug 15   1991-8-15   1991

# %%
gc_df = pd.read_sql('SELECT * FROM GENERIC_CONCEPT LIMIT 10;', con=engine)
gc_df
# Out:
#    CONCEPT_ID       CUI                       PREFERRED_NAME
# 0        1352  C0000788                  Abortion Applicants
# 1        1353  C0000937                           Accountant
# 2        1354  C0001687                  Adverse effects NEC
# 3        1355  C0002526  Amino Acids, Peptides, and Proteins
# 4        1356  C0002905             Anesthesia and Analgesia
# 5        1357  C0003043                             Animalia
# 6        1358  C0003062                              Animals
# 7        1359  C0003650                              Apudoma
# 8        1360  C0003965                           Ascomycota
# 9        1361  C0004063                              Assault

# %%
meta_df = pd.read_sql('SELECT * FROM METAINFO LIMIT 10;', con=engine)
meta_df
# Out:
#   DBVERSION SEMREPVERSION PUBMED_TODATE                   COMMENT
# 0       3.0           1.7    2016/12/31  Using regular semrep 1.7

# %%
pred_df = pd.read_sql('SELECT * FROM PREDICATION LIMIT 10;', con=engine)
pred_df
# Out:
#    PREDICATION_ID  SENTENCE_ID     PMID       PREDICATE SUBJECT_CUI  \
# 0          117370       248182  5585326      PROCESS_OF    C0021311
# 1          117371       248189  5659339         PART_OF    C0017725
# 2          117372       248189  5659339      PROCESS_OF    C0232338
# 3          117373       248198  5659341          TREATS    C0001041
# 4          117374       248200  4869506     LOCATION_OF    C0445623
# 5          117375       248201  4176301     LOCATION_OF    C0229671
# 6          117376       248202  5659342         PART_OF    C0021853
# 7          117377       248201  4176301       DIAGNOSES    C0231790
# 8          117378       248208  5659343      PROCESS_OF    C0232750
# 9          117379       248207  4171713  INTERACTS_WITH    C0005097
#
#       SUBJECT_NAME SUBJECT_SEMTYPE  SUBJECT_NOVELTY OBJECT_CUI  \
# 0        Infection            dsyn                0   C0020114
# 1          Glucose            bacs                1   C0022378
# ...

# %%
paux_df = pd.read_sql('SELECT * FROM PREDICATION_AUX LIMIT 10;', con=engine)
paux_df
# Out:
#    PREDICATION_AUX_ID  PREDICATION_ID    SUBJECT_TEXT  SUBJECT_DIST  \
# 0              117377          117370      infections             0
# 1              117378          117371         glucose             1
# 2              117379          117372      blood flow             4
# 3              117380          117373   acetylcholine             4
# 4              117381          117374  microorganisms             1
# 5              117382          117375           serum             0
# 6              117383          117376       intestine             0
# 7              117384          117377   Thompson test             1
# 8              117385          117378  Bile formation             1
# 9              117386          117379      benzpyrene             3
#
#    SUBJECT_MAXDIST  SUBJECT_START_INDEX  SUBJECT_END_INDEX  SUBJECT_SCORE  \
# 0                0                  158                168            888
# ...

# %%
sent_df = pd.read_sql('SELECT * FROM SENTENCE LIMIT 10;', con=engine)
sent_df
# Out:
#    SENTENCE_ID     PMID TYPE  NUMBER  \
# 0       248180  5585325   ti       1
# 1       248181  5585325   ti       2
# 2       248182  5585326   ti       1
# 3       248183  5585327   ti       1
# 4       248184  4971605   ti       1
# 5       248185  5585328   ti       1
# 6       248186  5585329   ti       1
# 7       248187  4971606   ti       1
# 8       248188  5585330   ti       1
# 9       248189  5659339   ti       1
#
#                                             SENTENCE
# 0  Mycoecology of willow and cottonwood lowland c...
# 1  Soil microfungi in the willow-cottonwood forests.
# 2  Human infections by Microsporon gypseum in Rom...
# 3  Environmental factors and growth of Histoplasm...
# 4  [On the fungistatic and barteriostatic propert...
# 5  Geophilic dermatophytes recovered from Rio Gra...
# 6  Effects of surface active agents on the suscep...
# 7  [Correlation between chemical constitution and...
# 8  T. mentagrophytes with macroconidia and spiral...
# ...

# %%
# %%time
pred_df1 = pd.read_sql('SELECT * FROM PREDICATION LIMIT 1000000;', con=engine)
# Out:
# CPU times: user 48.5 s, sys: 612 ms, total: 49.1 s
# Wall time: 49 s

# %%
'{:,}'.format(pred_df1.shape[0])
# Out:
# '1,000,000'
